# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3083, 12, 6, 195, 2, 3136, 46, 59, 156]
#
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()    
  #tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.964754
# Nearest to also: dagobert, malvern, reductionism, slightly, ridley, preserved, voroshilov, bedrooms,
# Nearest to to: norwich, figuratively, foreman, majdanek, tarot, entablature, sarris, kinase,
# Nearest to over: loans, test, delaunay, indifference, enrolled, guinea, rfcs, obedience,
# Nearest to their: stigma, rapper, nostrand, oneida, uploading, academic, supplanted, endless,
# Nearest to seven: englishmen, undergoing, quin, methylation, clos, ruin, hab, petra,
# Nearest to used: protestants, diab, scripted, teat, fierro, dtp, appear, fret,
# Nearest to s: arag, rahman, firmus, archives, referenced, eldr, heinrich, revolutionized,
# Nearest to or: unam, ghq, resigning, moria, mohenjo, kleene, facade, formalize,
# Nearest to four: exhaust, overlooking, vegetables, eiffel, together, tranquillity, cham, darfur,
# Nearest to however: apologists, haddo, undergo, meteorological, miraculous, salom, cropped, occasion,
# Nearest to three: minutemen, longue, southward, busman, marshallese, reformulated, invertebrate, punter,
# Nearest to after: microvision, stomping, magma, deserves, bracewell, zack, dependant, rgen,
# Nearest to it: admire, universite, aragonese, fernand, sampa, asymmetrical, mccullough, yury,
# Nearest to they: meanings, decius, vibrating, harmless, facilitating, dubbing, harmonicas, norbert,
# Nearest to system: shipment, legislative, stoke, unthinkable, bisexuals, moldova, budgetary, luminosity,
# Nearest to from: kantian, admin, unmik, giles, reductions, gdansk, rubric, castello,
# Average loss at step 2000: 4.363197
# Average loss at step 4000: 3.861639
# Average loss at step 6000: 3.779988
# Average loss at step 8000: 3.692660
# Average loss at step 10000: 3.612274
# Nearest to also: often, not, which, alyattes, malvern, grains, multicast, it,
# Nearest to to: tarot, would, constans, can, hx, magnetic, gametes, figuratively,
# Nearest to over: enrolled, loans, test, delaunay, mon, craps, cc, innocents,
# Nearest to their: his, the, its, endless, watt, decaying, oneida, savages,
# Nearest to seven: six, eight, four, five, three, nine, zero, two,
# Nearest to used: martians, inefficiencies, embryos, referred, sanjo, refusing, falkirk, mild,
# Nearest to s: his, revolutionized, gigabytes, and, balaguer, cavalli, replete, their,
# Nearest to or: and, chosenness, rhodesia, enciclopedia, nonexistent, thelema, possibly, hopkins,
# Nearest to four: six, five, eight, seven, three, two, nine, zero,
# Nearest to however: daimyo, vh, treble, pl, lewin, rafik, resting, subgroups,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to after: zack, showa, magus, jennings, inconclusive, deserves, stomping, rgen,
# Nearest to it: he, this, there, they, that, she, which, thrill,
# Nearest to they: he, it, i, there, lifting, who, not, yitzchak,
# Nearest to system: legislative, unthinkable, shipment, luminosity, stoke, guyer, bisexuals, moldova,
# Nearest to from: into, fireman, by, disgusting, coconut, miner, winthrop, landsat,
# Average loss at step 12000: 3.603217
# Average loss at step 14000: 3.572381
# Average loss at step 16000: 3.404521
# Average loss at step 18000: 3.460296
# Average loss at step 20000: 3.537744
# Nearest to also: which, now, often, not, below, it, usually, therapy,
# Nearest to to: would, constans, can, tarot, should, godzilla, not, hellespont,
# Nearest to over: mon, enrolled, loans, delaunay, test, nazism, from, craps,
# Nearest to their: his, its, the, her, ministerial, compressed, rubenstein, dunfermline,
# Nearest to seven: eight, six, three, four, nine, five, zero, two,
# Nearest to used: found, referred, martians, refusing, inefficiencies, sophistication, sanjo, kilojoules,
# Nearest to s: heinrich, gigabytes, hund, infractions, generalissimo, solf, byu, whose,
# Nearest to or: and, than, enciclopedia, fermilab, temporarily, esv, akm, chosenness,
# Nearest to four: three, six, seven, five, eight, two, nine, zero,
# Nearest to however: but, since, they, pips, under, darts, that, did,
# Nearest to three: four, five, seven, six, two, eight, zero, nine,
# Nearest to after: before, showa, bracewell, zack, magus, jennings, evaluating, from,
# Nearest to it: he, there, this, which, they, she, possible, also,
# Nearest to they: he, there, we, it, you, who, would, lifting,
# Nearest to system: legislative, unthinkable, excellent, sothoth, guyer, remixing, vandals, elisabetta,
# Nearest to from: into, in, castello, through, at, by, landsat, disgusting,
# Average loss at step 22000: 3.500575
# Average loss at step 24000: 3.487272
# Average loss at step 26000: 3.479020
# Average loss at step 28000: 3.477812
# Average loss at step 30000: 3.502459
# Nearest to also: often, now, which, it, below, still, dagobert, not,
# Nearest to to: would, can, hx, could, not, will, must, should,
# Nearest to over: mon, delaunay, loans, enrolled, ideally, through, across, turbofans,
# Nearest to their: his, its, her, the, these, some, smpte, many,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to used: found, known, referred, refusing, considered, called, def, necessary,
# Nearest to s: replete, his, per, and, spilling, shy, gigabytes, yolande,
# Nearest to or: and, but, depatie, expandable, than, haitians, elder, without,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to however: but, although, when, that, while, though, senile, laserdisc,
# Nearest to three: five, four, seven, eight, six, two, nine, zero,
# Nearest to after: before, when, during, showa, from, cagney, dumbarton, for,
# Nearest to it: he, there, this, they, she, which, also, often,
# Nearest to they: there, he, we, who, you, it, not, these,
# Nearest to system: systems, unthinkable, sothoth, legislative, guyer, wiesel, actions, regulators,
# Nearest to from: into, through, on, by, under, in, after, fireman,
# Average loss at step 32000: 3.500723
# Average loss at step 34000: 3.491522
# Average loss at step 36000: 3.456368
# Average loss at step 38000: 3.302886
# Average loss at step 40000: 3.430448
# Nearest to also: often, now, which, still, not, usually, soong, frequently,
# Nearest to to: will, can, would, could, from, should, may, tarot,
# Nearest to over: mon, across, delaunay, craps, through, ideally, nazism, finally,
# Nearest to their: its, his, her, the, these, your, biotite, my,
# Nearest to seven: five, six, eight, nine, four, three, zero, two,
# Nearest to used: found, referred, known, considered, refusing, held, necessary, available,
# Nearest to s: his, unbalanced, rogues, lama, orangutan, displace, neoclassical, vig,
# Nearest to or: and, than, nonexistent, but, billiards, a, virginals, fgc,
# Nearest to four: six, eight, seven, five, three, nine, two, one,
# Nearest to however: but, although, did, though, that, would, they, could,
# Nearest to three: four, seven, five, two, six, eight, nine, zero,
# Nearest to after: before, during, when, mci, through, from, while, had,
# Nearest to it: he, there, this, they, she, which, not, often,
# Nearest to they: there, we, he, you, it, who, not, these,
# Nearest to system: systems, sothoth, vandals, elisabetta, summoning, unthinkable, whiskers, actions,
# Nearest to from: into, in, through, to, of, fireman, on, during,
# Average loss at step 42000: 3.432792
# Average loss at step 44000: 3.453597
# Average loss at step 46000: 3.449512
# Average loss at step 48000: 3.352344
# Average loss at step 50000: 3.384234
# Nearest to also: now, often, which, still, frequently, soong, warfield, usually,
# Nearest to to: may, would, should, could, mystic, must, through, kushner,
# Nearest to over: across, through, mon, bootstrap, peterborough, arya, nazism, into,
# Nearest to their: its, his, her, your, the, both, these, some,
# Nearest to seven: six, eight, four, nine, five, three, zero, two,
# Nearest to used: found, known, referred, considered, available, designed, necessary, written,
# Nearest to s: and, gigabytes, vig, presbyters, rutgers, rubenstein, whose, dunraven,
# Nearest to or: and, than, repaired, kohl, while, armoured, ara, chicano,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to however: but, although, that, though, while, when, faiths, where,
# Nearest to three: four, six, seven, five, eight, nine, two, zero,
# Nearest to after: before, when, during, while, through, from, ibid, kaolinite,
# Nearest to it: he, she, there, this, they, adventurous, now, squirrel,
# Nearest to they: there, he, we, you, it, she, these, not,
# Nearest to system: systems, dormancy, unthinkable, sothoth, vandals, kristen, shipment, shook,
# Nearest to from: into, through, in, during, on, since, cassiopeia, after,
# Average loss at step 52000: 3.438842
# Average loss at step 54000: 3.428836
# Average loss at step 56000: 3.440075
# Average loss at step 58000: 3.395231
# Average loss at step 60000: 3.395013
# Nearest to also: now, often, still, sometimes, frequently, there, soong, which,
# Nearest to to: would, will, could, detrimental, mystic, may, crowther, tarot,
# Nearest to over: across, through, peterborough, around, into, between, mon, about,
# Nearest to their: its, his, her, the, your, my, these, smpte,
# Nearest to seven: four, eight, six, five, nine, three, zero, one,
# Nearest to used: found, known, designed, referred, considered, written, seen, necessary,
# Nearest to s: vig, larch, whose, notorious, omniscient, allosteric, byu, cavalli,
# Nearest to or: and, than, processing, but, while, nonexistent, breaching, vigilante,
# Nearest to four: five, seven, six, eight, three, nine, zero, two,
# Nearest to however: but, though, although, that, when, since, which, there,
# Nearest to three: five, four, six, seven, eight, two, nine, one,
# Nearest to after: before, during, when, while, despite, from, under, following,
# Nearest to it: he, there, this, she, they, which, not, usually,
# Nearest to they: we, there, you, he, she, these, it, not,
# Nearest to system: systems, unthinkable, predominance, whiskers, mental, jammu, livejournal, sothoth,
# Nearest to from: into, through, fireman, after, under, coconut, in, cosmic,
# Average loss at step 62000: 3.243250
# Average loss at step 64000: 3.258953
# Average loss at step 66000: 3.400722
# Average loss at step 68000: 3.389711
# Average loss at step 70000: 3.358872
# Nearest to also: now, still, often, which, formerly, usually, it, vortex,
# Nearest to to: would, will, can, must, for, should, diverging, could,
# Nearest to over: across, about, around, through, peterborough, evacuated, ideally, livia,
# Nearest to their: its, his, her, the, your, my, these, some,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to used: found, known, designed, referred, seen, available, written, necessary,
# Nearest to s: whose, grade, notorious, nea, rogues, cebit, omniscient, dsn,
# Nearest to or: and, while, nonexistent, without, but, tiling, mouthwash, than,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to however: but, although, though, while, when, that, where, since,
# Nearest to three: four, six, five, two, eight, seven, nine, zero,
# Nearest to after: before, during, when, while, despite, though, without, dumbarton,
# Nearest to it: he, there, she, this, they, still, also, usually,
# Nearest to they: we, there, he, you, it, she, who, questionable,
# Nearest to system: systems, program, vandals, company, columnists, arena, juneau, predominance,
# Nearest to from: into, through, fireman, in, before, by, averroes, employ,
# Average loss at step 72000: 3.376551
# Average loss at step 74000: 3.348318
# Average loss at step 76000: 3.320100
# Average loss at step 78000: 3.351661
# Average loss at step 80000: 3.382113
# Nearest to also: now, often, still, which, sometimes, traditionally, hbo, it,
# Nearest to to: tarot, would, should, will, detrimental, must, pump, sarris,
# Nearest to over: across, around, about, peterborough, between, evacuated, mon, off,
# Nearest to their: its, her, his, your, my, our, both, the,
# Nearest to seven: six, eight, four, nine, five, three, zero, one,
# Nearest to used: found, known, referred, designed, seen, written, available, necessary,
# Nearest to s: whose, cb, passy, formalisms, scabbard, isbn, breeder, snk,
# Nearest to or: and, than, while, gypsys, non, rotor, nonexistent, tailor,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to however: although, but, though, that, while, where, when, sec,
# Nearest to three: four, five, seven, six, eight, two, nine, zero,
# Nearest to after: before, during, when, despite, while, without, erskine, until,
# Nearest to it: he, she, there, this, they, always, often, not,
# Nearest to they: we, he, there, you, she, it, not, who,
# Nearest to system: systems, program, company, juneau, dominica, vandals, network, lytton,
# Nearest to from: through, into, within, by, pontifical, across, munda, during,
# Average loss at step 82000: 3.408062
# Average loss at step 84000: 3.411666
# Average loss at step 86000: 3.391717
# Average loss at step 88000: 3.355141
# Average loss at step 90000: 3.361405
# Nearest to also: now, often, still, which, sometimes, usually, frequently, never,
# Nearest to to: will, would, curtailing, tarot, diverging, should, criticizing, moabite,
# Nearest to over: across, around, about, off, peterborough, evacuated, through, between,
# Nearest to their: its, his, her, your, my, our, the, whose,
# Nearest to seven: eight, nine, five, six, four, three, one, zero,
# Nearest to used: found, designed, known, referred, seen, considered, employed, able,
# Nearest to s: whose, avengers, formalisms, his, omniscient, isbn, dsn, yamamoto,
# Nearest to or: and, expandable, than, parisians, wrecked, while, tiling, polled,
# Nearest to four: five, seven, three, six, eight, nine, two, one,
# Nearest to however: but, although, that, though, since, while, today, where,
# Nearest to three: four, five, two, seven, eight, six, nine, zero,
# Nearest to after: before, during, when, despite, without, while, until, for,
# Nearest to it: he, she, there, this, they, itself, often, usually,
# Nearest to they: we, you, there, he, she, it, who, these,
# Nearest to system: systems, program, mental, network, rented, predominance, vandals, orbit,
# Nearest to from: through, into, during, fireman, in, by, under, munda,
# Average loss at step 92000: 3.396408
# Average loss at step 94000: 3.255377
# Average loss at step 96000: 3.352560
# Average loss at step 98000: 3.244644
# Average loss at step 100000: 3.355846
# Nearest to also: now, still, often, actually, sometimes, usually, never, frequently,
# Nearest to to: could, will, would, can, must, tarot, should, cannot,
# Nearest to over: across, around, about, evacuated, off, between, annotations, within,
# Nearest to their: its, his, her, your, my, our, these, fevers,
# Nearest to seven: four, eight, five, six, nine, three, zero, two,
# Nearest to used: found, designed, referred, considered, employed, applied, able, seen,
# Nearest to s: whose, his, notorious, passy, themed, formalisms, dsn, replete,
# Nearest to or: and, than, without, mouthwash, nonexistent, ailment, shattuck, westerner,
# Nearest to four: seven, five, six, eight, three, nine, two, zero,
# Nearest to however: but, although, that, though, especially, while, where, since,
# Nearest to three: five, four, seven, two, six, eight, nine, zero,
# Nearest to after: before, during, when, without, despite, for, while, following,
# Nearest to it: he, she, there, this, they, borderline, cronenberg, which,
# Nearest to they: we, there, you, he, she, it, these, who,
# Nearest to system: systems, program, apollon, mental, vandals, method, network, predominance,
# Nearest to from: through, into, fireman, in, landsat, soi, across, coconut,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /Library/Python/2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Function to generate a training batch for the skip-gram model. Source:
#     http://www.thushv.com/natural_language_processing/word2vec-part-2-nlp-with-deep-learning-with-tensorflow-cbow/

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side
    
    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)
    
    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself
        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]
 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels  

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window))
    print('    batch:', batch)
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: [[5239   12]
#  [3084    6]
#  [  12  195]
#  [   6    2]
#  [ 195 3137]
#  [   2   46]
#  [3137   59]
#  [  46  156]]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with skip_window = 2:
#     batch: [[5239 3084    6  195]
#  [3084   12  195    2]
#  [  12    6    2 3137]
#  [   6  195 3137   46]
#  [ 195    2   46   59]
#  [   2 3137   59  156]
#  [3137   46  156  128]
#  [  46   59  128  742]]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Train a CBOW model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
#valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
#valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))

num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.

  # Look up embeddings for inputs.  
  embeds = None
  for i in range(2*skip_window):
    embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
    print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
    emb_x,emb_y = embedding_i.get_shape().as_list()
    if embeds is None:
        embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
    else:
        embeds = tf.concat(2,[embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])])

  assert embeds.get_shape().as_list()[2]==2*skip_window
  print("Concat embedding size: %s"%embeds.get_shape().as_list())
  avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False)
  print("Avg embedding size: %s"%avg_embed.get_shape().as_list())

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed,
                       train_labels, num_sampled, vocabulary_size))
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
 
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embedding 0 shape: [128, 128]
# embedding 1 shape: [128, 128]
# Concat embedding size: [128, 128, 2]
# Avg embedding size: [128, 128]

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.253619
# Nearest to use: confectionery, berlioz, priesthood, resonant, cascading, blish, cid, lexis,
# Nearest to were: cute, kan, drosophila, clubhouse, spines, fujitsu, futility, defector,
# Nearest to been: visconti, copacabana, therefore, shevat, consultations, materialism, carom, gin,
# Nearest to used: sponge, grain, palestinian, inked, simple, annales, punks, ideals,
# Nearest to people: galley, tawhid, fragment, colonels, patrolling, pett, dipyramid, janice,
# Nearest to was: section, golem, colonised, seven, compliant, chirac, confusing, survivors,
# Nearest to d: android, cur, peripherals, saarland, antipope, bcp, cotswolds, ufo,
# Nearest to as: lopez, lecompton, agis, lsi, micheal, emigrate, chandra, designed,
# Nearest to and: geographically, dma, reinsurance, kazakhstani, sunrise, virginity, aon, plutinos,
# Nearest to state: balkans, jeanette, preface, sibley, integrins, foray, ut, exiled,
# Nearest to there: measures, atmospheric, receive, tyrannical, leningrad, privy, darwinian, sequencing,
# Nearest to UNK: tco, ciconiiformes, immolation, samples, toro, bat, pinch, xl,
# Nearest to for: fawn, werner, professorship, unpredictability, harley, rota, apprentices, its,
# Nearest to than: battleship, alston, firstborn, flask, alarm, lebrun, unaccustomed, newman,
# Nearest to zero: competitors, telecasts, subject, dude, citation, illusory, substance, matti,
# Nearest to s: juggalo, palais, rehab, bassoon, ordinations, overwhelms, leigh, pilgrim,
# Average loss at step 2000: 4.032770
# Average loss at step 4000: 3.508135
# Average loss at step 6000: 3.340286
# Average loss at step 8000: 3.186263
# Average loss at step 10000: 3.147314
# Nearest to use: dystopia, confectionery, priesthood, normalcy, cosmo, cid, southerly, lexis,
# Nearest to were: are, was, had, kan, eee, rgya, boyce, foreseen,
# Nearest to been: train, chained, copacabana, lana, perpignan, be, were, opens,
# Nearest to used: said, palestinian, annales, moving, fairies, interrogation, informs, denotes,
# Nearest to people: colonels, galley, lobes, years, herbal, spokesperson, nested, tawhid,
# Nearest to was: is, had, were, has, became, be, although, maoi,
# Nearest to d: b, methodus, reach, trillion, carolla, walkers, mizrahi, haikai,
# Nearest to as: hearn, simpsons, specific, lars, rationalism, ambergris, dolce, nonmetals,
# Nearest to and: or, spoons, muses, allman, but, kammu, perthshire, lacaille,
# Nearest to state: jeanette, antioxidant, zoom, foray, package, bainbridge, integrins, whipped,
# Nearest to there: they, often, it, darwinian, measures, generally, we, tyrannical,
# Nearest to UNK: squirrel, pinch, et, brett, larsen, ruth, volley, shall,
# Nearest to for: coastal, than, disposed, broadening, bulgarian, using, in, lamarck,
# Nearest to than: for, unaccustomed, battleship, fairgrounds, gantry, thorax, philosophically, dystopian,
# Nearest to zero: six, three, eight, five, nine, seven, four, two,
# Nearest to s: deteriorate, his, ammianus, franjo, robert, bassoon, erroneous, svante,
# Average loss at step 12000: 3.167551
# Average loss at step 14000: 3.127783
# Average loss at step 16000: 3.143281
# Average loss at step 18000: 3.102544
# Average loss at step 20000: 2.997178
# Nearest to use: dystopia, gabonese, sale, cosmo, lexis, motion, heracles, rx,
# Nearest to were: are, was, have, be, kan, been, had, eee,
# Nearest to been: be, become, was, train, were, chained, copacabana, plays,
# Nearest to used: known, moving, described, available, annales, produced, referred, said,
# Nearest to people: years, rei, colonels, nested, patrolling, braintree, maternal, futuristic,
# Nearest to was: is, became, were, had, has, been, be, did,
# Nearest to d: b, methodus, trillion, walkers, haikai, carolla, chuppah, saarland,
# Nearest to as: ambergris, dolce, hearn, nonmetals, simpsons, balmoral, lars, suppressor,
# Nearest to and: or, but, teaspoon, piston, ptolemaic, mortar, unresponsive, ranked,
# Nearest to state: package, zoom, integrins, margarine, balkans, whipped, azo, jeanette,
# Nearest to there: they, it, often, generally, darwinian, ncs, tyrannical, he,
# Nearest to UNK: commercialization, marxian, et, adversarial, r, stung, pinch, sensors,
# Nearest to for: coastal, than, using, broadening, bulgarian, harley, thematically, when,
# Nearest to than: or, for, therapies, unaccustomed, thorax, gantry, impacting, fairgrounds,
# Nearest to zero: seven, eight, six, nine, four, five, three, u,
# Nearest to s: robert, his, franjo, ammianus, bassoon, deteriorate, erroneous, natchez,
# Average loss at step 22000: 3.054342
# Average loss at step 24000: 3.022464
# Average loss at step 26000: 2.989402
# Average loss at step 28000: 3.011560
# Average loss at step 30000: 2.989051
# Nearest to use: gabonese, dystopia, motion, sale, lexis, rx, heracles, end,
# Nearest to were: are, have, was, had, been, be, eee, boyce,
# Nearest to been: be, become, was, were, train, plays, chained, previously,
# Nearest to used: available, known, described, referred, intended, called, produced, moving,
# Nearest to people: years, nested, rei, ldots, those, futuristic, lobes, ottonian,
# Nearest to was: is, became, were, had, has, been, be, seriously,
# Nearest to d: b, methodus, chuppah, carolla, haikai, saarland, memorial, reach,
# Nearest to as: ambergris, balmoral, simpsons, mirror, beckett, entitles, nonmetals, hearn,
# Nearest to and: or, but, pearson, closing, while, piston, muses, modernism,
# Nearest to state: package, zoom, preface, government, antioxidant, integrins, margarine, balkans,
# Nearest to there: they, it, he, she, darwinian, generally, trams, punic,
# Nearest to UNK: et, pins, la, j, ellsworth, von, acquittal, bolton,
# Nearest to for: coastal, when, monosyllabic, gabal, riverine, thematically, if, vesicle,
# Nearest to than: or, thorax, gantry, therapies, impacting, naturalization, unaccustomed, unpublished,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to s: robert, natchez, wiccan, tramiel, deteriorate, franjo, custody, ibos,
# Average loss at step 32000: 2.841779
# Average loss at step 34000: 2.947056
# Average loss at step 36000: 2.937766
# Average loss at step 38000: 2.939104
# Average loss at step 40000: 2.921233
# Nearest to use: gabonese, motion, lexis, douglass, aspartic, rx, inquisitorial, sale,
# Nearest to were: are, have, had, was, been, be, chiaroscuro, eee,
# Nearest to been: be, become, were, was, plays, previously, riverview, train,
# Nearest to used: known, available, referred, described, produced, intended, performed, called,
# Nearest to people: nested, those, ldots, pedestal, futuristic, philosophers, rei, years,
# Nearest to was: is, became, were, had, has, be, been, seriously,
# Nearest to d: b, methodus, chuppah, memorial, saarland, walkers, trillion, incan,
# Nearest to as: balmoral, simpsons, ambergris, mirror, generalised, dolce, micheal, ono,
# Nearest to and: or, but, empiricist, closing, piston, accessing, teaspoon, ugo,
# Nearest to state: government, package, integrins, zoom, margarine, tallest, antioxidant, whipped,
# Nearest to there: they, it, he, she, we, darwinian, trams, often,
# Nearest to UNK: talent, ha, squirrel, zanu, hybrid, readability, carter, cordell,
# Nearest to for: when, if, after, vesicle, monosyllabic, against, resurrecting, thematically,
# Nearest to than: or, therapies, gantry, much, thorax, barrios, impacting, but,
# Nearest to zero: six, seven, eight, five, four, three, nine, u,
# Nearest to s: custody, ammianus, franjo, natchez, isbn, midgard, robert, his,
# Average loss at step 42000: 2.938254
# Average loss at step 44000: 2.945004
# Average loss at step 46000: 2.903224
# Average loss at step 48000: 2.866703
# Average loss at step 50000: 2.841318
# Nearest to use: gabonese, motion, douglass, sale, lexis, adaptations, form, aspartic,
# Nearest to were: are, have, had, was, been, be, eee, chiaroscuro,
# Nearest to been: be, become, were, was, previously, already, riverview, train,
# Nearest to used: available, known, referred, described, called, produced, performed, considered,
# Nearest to people: philosophers, jews, nested, ldots, futuristic, those, ottonian, slag,
# Nearest to was: is, became, had, were, has, been, be, appears,
# Nearest to d: b, methodus, memorial, dflp, carolla, incan, semiology, precipitated,
# Nearest to as: lars, nonmetals, balmoral, transgendered, simpsons, hearn, nurse, isometry,
# Nearest to and: or, but, while, artisan, teaspoon, than, pearson, encompass,
# Nearest to state: government, package, city, cassell, azo, sadducees, tallest, antioxidant,
# Nearest to there: they, it, he, she, trams, we, darwinian, often,
# Nearest to UNK: watergate, et, troupes, ha, adversarial, talent, drusus, brett,
# Nearest to for: when, if, lamarck, harley, riverine, randomized, against, vesicle,
# Nearest to than: or, slightly, barrios, impacting, and, far, much, gantry,
# Nearest to zero: eight, five, four, seven, six, nine, three, two,
# Nearest to s: his, custody, robert, ammianus, bessie, malmesbury, natchez, your,
# Average loss at step 52000: 2.883581
# Average loss at step 54000: 2.865926
# Average loss at step 56000: 2.857851
# Average loss at step 58000: 2.763202
# Average loss at step 60000: 2.828182
# Nearest to use: gabonese, motion, douglass, inquisitorial, adaptations, sale, aspartic, lexis,
# Nearest to were: are, have, was, had, been, chiaroscuro, be, eee,
# Nearest to been: be, become, were, previously, was, already, riverview, fallen,
# Nearest to used: described, known, available, referred, called, viewed, regarded, produced,
# Nearest to people: philosophers, children, men, jews, nested, those, ldots, ottonian,
# Nearest to was: is, had, became, has, were, appears, been, be,
# Nearest to d: b, methodus, carolla, semiology, incan, memorial, trillion, chuppah,
# Nearest to as: balmoral, hearn, transgendered, simpsons, ono, britannicus, concurred, studi,
# Nearest to and: but, or, although, while, mcmillan, teaspoon, neurological, livin,
# Nearest to state: government, margarine, package, azo, apartheid, cassell, capitalised, tallest,
# Nearest to there: they, it, he, she, trams, we, generally, darwinian,
# Nearest to UNK: l, et, brett, leitrim, marston, j, quakers, acute,
# Nearest to for: harley, gabal, without, if, fawn, when, riverine, fundamental,
# Nearest to than: or, slightly, barrios, natura, impacting, but, thorax, glycoproteins,
# Nearest to zero: five, seven, six, four, eight, three, nine, kg,
# Nearest to s: robert, his, natchez, condor, ammianus, ibos, custody, arduous,
# Average loss at step 62000: 2.833779
# Average loss at step 64000: 2.780074
# Average loss at step 66000: 2.768342
# Average loss at step 68000: 2.721014
# Average loss at step 70000: 2.775958
# Nearest to use: gabonese, aspartic, sense, inquisitorial, motion, adaptations, sale, study,
# Nearest to were: are, have, was, had, been, chiaroscuro, be, weasels,
# Nearest to been: be, become, were, was, riverview, previously, fallen, already,
# Nearest to used: described, referred, available, known, viewed, needed, produced, intended,
# Nearest to people: men, jews, philosophers, women, troops, children, those, ldots,
# Nearest to was: is, became, had, were, has, be, been, zum,
# Nearest to d: b, methodus, carolla, semiology, chuppah, du, incan, mizrahi,
# Nearest to as: balmoral, ono, britannicus, simpsons, transgendered, generalised, mirror, nurse,
# Nearest to and: or, but, while, although, teaspoon, centralised, livin, deontology,
# Nearest to state: government, national, azo, cassell, apartheid, physician, grigory, package,
# Nearest to there: they, it, he, she, we, still, sometimes, generally,
# Nearest to UNK: leitrim, prequel, aru, projectiles, rambam, antiquated, zane, drusus,
# Nearest to for: against, if, despite, towards, fealty, permits, monosyllabic, vesicle,
# Nearest to than: or, barrios, natura, much, slightly, impacting, therapies, thorax,
# Nearest to zero: five, six, eight, seven, four, three, nine, two,
# Nearest to s: his, whose, her, natchez, your, isbn, robert, arduous,
# Average loss at step 72000: 2.801073
# Average loss at step 74000: 2.659569
# Average loss at step 76000: 2.804590
# Average loss at step 78000: 2.824267
# Average loss at step 80000: 2.785703
# Nearest to use: gabonese, sense, adaptations, aspartic, sale, motion, study, gollum,
# Nearest to were: are, was, have, had, been, chiaroscuro, be, eee,
# Nearest to been: become, be, were, was, fallen, riverview, already, previously,
# Nearest to used: known, described, available, referred, produced, needed, seen, defined,
# Nearest to people: men, jews, philosophers, children, women, troops, those, ldots,
# Nearest to was: is, became, were, has, had, been, appears, be,
# Nearest to d: b, methodus, carolla, incan, chuppah, walkers, semiology, dflp,
# Nearest to as: balmoral, simpsons, concurred, ono, britannicus, transgendered, dolce, hearn,
# Nearest to and: or, but, including, although, however, eradicating, teaspoon, spoons,
# Nearest to state: government, national, physician, azo, cassell, zoom, grigory, intrepid,
# Nearest to there: they, it, he, we, she, cryptozoology, generally, still,
# Nearest to UNK: et, la, ha, al, rambam, der, gr, marston,
# Nearest to for: when, despite, after, without, against, crono, although, silmarillion,
# Nearest to than: or, barrios, much, slightly, dodge, aphorisms, natura, therapies,
# Nearest to zero: five, six, eight, seven, four, three, nine, two,
# Nearest to s: whose, natchez, hunter, ammianus, lauderdale, graded, isbn, tamm,
# Average loss at step 82000: 2.674789
# Average loss at step 84000: 2.776087
# Average loss at step 86000: 2.744890
# Average loss at step 88000: 2.755135
# Average loss at step 90000: 2.741140
# Nearest to use: sense, gabonese, aspartic, allow, adaptations, writ, need, study,
# Nearest to were: are, have, had, been, was, chiaroscuro, those, eee,
# Nearest to been: become, be, fallen, were, riverview, previously, already, was,
# Nearest to used: described, known, referred, available, produced, called, needed, performed,
# Nearest to people: men, jews, women, troops, children, philosophers, students, sidi,
# Nearest to was: is, has, became, had, appears, were, be, been,
# Nearest to d: b, methodus, p, carolla, chuppah, incan, preparedness, semiology,
# Nearest to as: simpsons, balmoral, glycolipids, ono, nurse, concurred, nostra, micheal,
# Nearest to and: or, but, including, teaspoon, although, deontology, piston, pearson,
# Nearest to state: national, government, obeying, physician, city, grigory, cassell, azo,
# Nearest to there: they, it, she, he, we, cryptozoology, yom, electroplating,
# Nearest to UNK: ha, et, maser, pinch, wilt, http, franchisee, plunging,
# Nearest to for: silmarillion, despite, when, walcott, if, without, quartz, although,
# Nearest to than: or, natura, slightly, barrios, dodge, acknowledge, aphorisms, calculate,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to s: whose, tailor, natchez, lauderdale, hunter, patty, wahid, midgard,
# Average loss at step 92000: 2.689841
# Average loss at step 94000: 2.727270
# Average loss at step 96000: 2.708961
# Average loss at step 98000: 2.383193
# Average loss at step 100000: 2.419578
# Nearest to use: gabonese, aspartic, sense, allow, adaptations, inquisitorial, need, fastest,
# Nearest to were: are, have, was, had, been, be, chiaroscuro, include,
# Nearest to been: become, be, fallen, already, were, previously, riverview, recently,
# Nearest to used: described, known, referred, needed, available, produced, called, defined,
# Nearest to people: men, women, jews, children, troops, persons, man, philosophers,
# Nearest to was: is, became, had, were, be, has, wrote, appears,
# Nearest to d: b, methodus, bulgarian, du, semiology, waldemar, dflp, leigh,
# Nearest to as: balmoral, cir, ono, ambergris, simpsons, concurred, transgendered, glycolipids,
# Nearest to and: or, but, however, including, teaspoon, although, while, livin,
# Nearest to state: national, government, states, obeying, grigory, cassell, sadducees, city,
# Nearest to there: they, he, it, she, we, still, sometimes, you,
# Nearest to UNK: ha, stemmed, watergate, gravesite, chemist, clark, crooked, tigre,
# Nearest to for: after, against, monosyllabic, when, despite, towards, if, turntables,
# Nearest to than: or, slightly, natura, much, dodge, barrios, morr, therapies,
# Nearest to zero: six, five, seven, four, eight, three, nine, two,
# Nearest to s: american, natchez, midgard, whose, condor, wahid, colitis, hose,

# %% [markdown]
# comparing the quality of the models:
#
# skip-gram loss at step 100000: 3.36
#
# CBOW loss at stap 100000: 2.42

# %%
# TSNE representation

num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /Library/Python/2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
